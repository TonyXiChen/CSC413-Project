# %%
import io
import os
import subprocess

import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

from textwrap import fill

# %%
def train_lora(base_model="runwayml/stable-diffusion-v1-5",
               output_dir=os.getcwd() + '/LoRA', dataset="dataset.parquet",
               num_train_epochs=3, checkpointing_steps=100, max_train_steps=1000,
               learning_rate=1e-04, max_grad_norm=2, precision="bf16",
               validation_prompt="An illustration of Pikachu, a yellow, electric-type Pokemon"):

    def parquet_to_imagefolder(output_dir, dataset):
        imagefolder_dir = os.path.join(output_dir, os.path.splitext(dataset)[0])
        metadata_csv_path = os.path.join(imagefolder_dir, 'metadata.csv')
        
        os.makedirs(imagefolder_dir, exist_ok=True)
        
        df = pd.read_parquet(dataset)
        
        metadata = []
        
        for index, row in df.iterrows():
            image_data = row['image']['bytes']
            text = row['text']
        
            image_name = f'{index}.jpg'
            image_path = os.path.join(imagefolder_dir, image_name)
        
            image = Image.open(io.BytesIO(image_data))
            image.save(image_path)
        
            metadata.append({'file_name': image_name, 'text': text})
        
        
        metadata_df = pd.DataFrame(metadata)
        metadata_df.to_csv(metadata_csv_path, index=False)
    
        return None
    
    def run_command_in_notebook(command):
        process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
    
        while True:
            output = process.stdout.readline()
            if output == '' and process.poll() is not None:
                break
            if output:
                print(output.strip())
        
        return_code = process.poll()
        if return_code:
            print(f"Command exited with error code {return_code}")
    
    command = [
        'accelerate',
        'launch',
        "--mixed_precision=" + str(precision),
        'train_text_to_image_lora.py',
        '--pretrained_model_name_or_path=' + str(base_model),
        '--train_data_dir=' + os.path.join(output_dir, os.path.splitext(dataset)[0]),
        '--resolution=512',
        '--train_batch_size=8',
        '--center_crop',
        '--num_train_epochs=' + str(num_train_epochs),
        '--checkpointing_steps=' + str(checkpointing_steps),
        '--max_train_steps=' + str(max_train_steps),
        '--learning_rate=' + str(learning_rate),
        '--max_grad_norm=' + str(max_grad_norm),
        '--lr_scheduler=constant',
        '--lr_warmup_steps=0',
        '--seed=413',
        '--output_dir=' + str(output_dir),
        '--report_to=wandb',
        '--validation_prompt=' + str(validation_prompt),
        '--num_validation_images=1'
    ]

    parquet_to_imagefolder(output_dir, dataset)
    
    run_command_in_notebook(command)
    
    return None

# %%
train_lora()
# Out:
# 04/15/2024 03:29:52 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: bf16
#
# {'sample_max_value', 'variance_type', 'prediction_type', 'clip_sample_range', 'dynamic_thresholding_ratio', 'thresholding', 'rescale_betas_zero_snr', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# {'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# {'time_embedding_act_fn', 'conv_in_kernel', 'cross_attention_norm', 'projection_class_embeddings_input_dim', 'resnet_out_scale_factor', 'resnet_time_scale_shift', 'upcast_attention', 'addition_embed_type_num_heads', 'time_cond_proj_dim', 'mid_block_type', 'encoder_hid_dim_type', 'addition_time_embed_dim', 'reverse_transformer_layers_per_block', 'mid_block_only_cross_attention', 'time_embedding_type', 'encoder_hid_dim', 'only_cross_attention', 'class_embed_type', 'dual_cross_attention', 'num_class_embeds', 'class_embeddings_concat', 'dropout', 'addition_embed_type', 'time_embedding_dim', 'use_linear_projection', 'transformer_layers_per_block', 'conv_out_kernel', 'num_attention_heads', 'timestep_post_act', 'attention_type', 'resnet_skip_time_act'} was not found in config. Values will be initialized to default values.
#
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 32 examples [00:00, 2064.13 examples/s]
# wandb: Currently logged in as: tonyxichen. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in X:\Jupyter\csc413_project\wandb\run-20240415_033003-o5c5vb4a
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run splendid-mountain-37
# wandb:  View project at https://wandb.ai/tonyxichen/text2image-fine-tune
# wandb:  View run at https://wandb.ai/tonyxichen/text2image-fine-tune/runs/o5c5vb4a
# 04/15/2024 03:30:04 - INFO - __main__ - ***** Running training *****
# 04/15/2024 03:30:04 - INFO - __main__ -   Num examples = 32
# 04/15/2024 03:30:04 - INFO - __main__ -   Num Epochs = 250
# 04/15/2024 03:30:04 - INFO - __main__ -   Instantaneous batch size per device = 8
# 04/15/2024 03:30:04 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 8
# 04/15/2024 03:30:04 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/15/2024 03:30:04 - INFO - __main__ -   Total optimization steps = 1000
#
# Steps:   0%|          | 0/1000 [00:00<?, ?it/s]C:\Users\Tony\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\models\attention_processor.py:1276: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
# hidden_states = F.scaled_dot_product_attention(
#
# Steps:   0%|          | 1/1000 [00:01<30:57,  1.86s/it]
# Steps:   0%|          | 1/1000 [00:01<30:57,  1.86s/it, lr=0.0001, step_loss=0.0503]
# Steps:   0%|          | 2/1000 [00:02<20:04,  1.21s/it, lr=0.0001, step_loss=0.0503]
# Steps:   0%|          | 2/1000 [00:02<20:04,  1.21s/it, lr=0.0001, step_loss=0.0309]
# Steps:   0%|          | 3/1000 [00:03<17:25,  1.05s/it, lr=0.0001, step_loss=0.0309]
# Steps:   0%|          | 3/1000 [00:03<17:25,  1.05s/it, lr=0.0001, step_loss=0.0515]
# Steps:   0%|          | 4/1000 [00:04<15:08,  1.10it/s, lr=0.0001, step_loss=0.0515]
# Steps:   0%|          | 4/1000 [00:04<15:08,  1.10it/s, lr=0.0001, step_loss=0.0885]04/15/2024 03:30:08 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.52it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.73it/s]
#
# Steps:   0%|          | 5/1000 [00:13<1:04:47,  3.91s/it, lr=0.0001, step_loss=0.0885]
# Steps:   0%|          | 5/1000 [00:13<1:04:47,  3.91s/it, lr=0.0001, step_loss=0.142]
# Steps:   1%|          | 6/1000 [00:14<47:18,  2.86s/it, lr=0.0001, step_loss=0.142]
# Steps:   1%|          | 6/1000 [00:14<47:18,  2.86s/it, lr=0.0001, step_loss=0.0308]
# Steps:   1%|          | 7/1000 [00:15<36:07,  2.18s/it, lr=0.0001, step_loss=0.0308]
# Steps:   1%|          | 7/1000 [00:15<36:07,  2.18s/it, lr=0.0001, step_loss=0.0955]
# Steps:   1%|          | 8/1000 [00:15<28:18,  1.71s/it, lr=0.0001, step_loss=0.0955]
# Steps:   1%|          | 8/1000 [00:15<28:18,  1.71s/it, lr=0.0001, step_loss=0.0538]04/15/2024 03:30:19 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.58it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   1%|          | 9/1000 [00:24<1:04:41,  3.92s/it, lr=0.0001, step_loss=0.0538]
# Steps:   1%|          | 9/1000 [00:24<1:04:41,  3.92s/it, lr=0.0001, step_loss=0.054]
# Steps:   1%|          | 10/1000 [00:25<48:43,  2.95s/it, lr=0.0001, step_loss=0.054]
# Steps:   1%|          | 10/1000 [00:25<48:43,  2.95s/it, lr=0.0001, step_loss=0.0318]
# Steps:   1%|          | 11/1000 [00:26<37:38,  2.28s/it, lr=0.0001, step_loss=0.0318]
# Steps:   1%|          | 11/1000 [00:26<37:38,  2.28s/it, lr=0.0001, step_loss=0.0456]
# Steps:   1%|          | 12/1000 [00:26<29:44,  1.81s/it, lr=0.0001, step_loss=0.0456]
# Steps:   1%|          | 12/1000 [00:26<29:44,  1.81s/it, lr=0.0001, step_loss=0.0382]04/15/2024 03:30:30 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.87it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   1%|▏         | 13/1000 [00:35<1:03:42,  3.87s/it, lr=0.0001, step_loss=0.0382]
# Steps:   1%|▏         | 13/1000 [00:35<1:03:42,  3.87s/it, lr=0.0001, step_loss=0.0418]
# Steps:   1%|▏         | 14/1000 [00:36<48:32,  2.95s/it, lr=0.0001, step_loss=0.0418]
# Steps:   1%|▏         | 14/1000 [00:36<48:32,  2.95s/it, lr=0.0001, step_loss=0.0353]
# Steps:   2%|▏         | 15/1000 [00:36<37:48,  2.30s/it, lr=0.0001, step_loss=0.0353]
# Steps:   2%|▏         | 15/1000 [00:37<37:48,  2.30s/it, lr=0.0001, step_loss=0.067]
# Steps:   2%|▏         | 16/1000 [00:37<29:52,  1.82s/it, lr=0.0001, step_loss=0.067]
# Steps:   2%|▏         | 16/1000 [00:37<29:52,  1.82s/it, lr=0.0001, step_loss=0.0468]04/15/2024 03:30:41 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   2%|▏         | 17/1000 [00:46<1:03:54,  3.90s/it, lr=0.0001, step_loss=0.0468]
# Steps:   2%|▏         | 17/1000 [00:46<1:03:54,  3.90s/it, lr=0.0001, step_loss=0.0554]
# Steps:   2%|▏         | 18/1000 [00:47<48:39,  2.97s/it, lr=0.0001, step_loss=0.0554]
# Steps:   2%|▏         | 18/1000 [00:47<48:39,  2.97s/it, lr=0.0001, step_loss=0.0574]
# Steps:   2%|▏         | 19/1000 [00:48<37:50,  2.31s/it, lr=0.0001, step_loss=0.0574]
# Steps:   2%|▏         | 19/1000 [00:48<37:50,  2.31s/it, lr=0.0001, step_loss=0.0366]
# Steps:   2%|▏         | 20/1000 [00:48<29:58,  1.84s/it, lr=0.0001, step_loss=0.0366]
# Steps:   2%|▏         | 20/1000 [00:48<29:58,  1.84s/it, lr=0.0001, step_loss=0.0481]04/15/2024 03:30:52 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.52it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   2%|▏         | 21/1000 [00:57<1:04:25,  3.95s/it, lr=0.0001, step_loss=0.0481]
# Steps:   2%|▏         | 21/1000 [00:57<1:04:25,  3.95s/it, lr=0.0001, step_loss=0.035]
# Steps:   2%|▏         | 22/1000 [00:58<48:51,  3.00s/it, lr=0.0001, step_loss=0.035]
# Steps:   2%|▏         | 22/1000 [00:58<48:51,  3.00s/it, lr=0.0001, step_loss=0.045]
# Steps:   2%|▏         | 23/1000 [00:59<38:03,  2.34s/it, lr=0.0001, step_loss=0.045]
# Steps:   2%|▏         | 23/1000 [00:59<38:03,  2.34s/it, lr=0.0001, step_loss=0.0342]
# Steps:   2%|▏         | 24/1000 [00:59<30:07,  1.85s/it, lr=0.0001, step_loss=0.0342]
# Steps:   2%|▏         | 24/1000 [01:00<30:07,  1.85s/it, lr=0.0001, step_loss=0.0799]04/15/2024 03:31:04 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.57it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.75it/s]
#
# Steps:   2%|▎         | 25/1000 [01:08<1:02:21,  3.84s/it, lr=0.0001, step_loss=0.0799]
# Steps:   2%|▎         | 25/1000 [01:08<1:02:21,  3.84s/it, lr=0.0001, step_loss=0.096]
# Steps:   3%|▎         | 26/1000 [01:09<47:38,  2.93s/it, lr=0.0001, step_loss=0.096]
# Steps:   3%|▎         | 26/1000 [01:09<47:38,  2.93s/it, lr=0.0001, step_loss=0.0688]
# Steps:   3%|▎         | 27/1000 [01:10<37:15,  2.30s/it, lr=0.0001, step_loss=0.0688]
# Steps:   3%|▎         | 27/1000 [01:10<37:15,  2.30s/it, lr=0.0001, step_loss=0.092]
# Steps:   3%|▎         | 28/1000 [01:10<29:28,  1.82s/it, lr=0.0001, step_loss=0.092]
# Steps:   3%|▎         | 28/1000 [01:10<29:28,  1.82s/it, lr=0.0001, step_loss=0.0347]04/15/2024 03:31:14 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.54it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   3%|▎         | 29/1000 [01:19<1:02:38,  3.87s/it, lr=0.0001, step_loss=0.0347]
# Steps:   3%|▎         | 29/1000 [01:19<1:02:38,  3.87s/it, lr=0.0001, step_loss=0.0333]
# Steps:   3%|▎         | 30/1000 [01:20<47:39,  2.95s/it, lr=0.0001, step_loss=0.0333]
# Steps:   3%|▎         | 30/1000 [01:20<47:39,  2.95s/it, lr=0.0001, step_loss=0.08]
# Steps:   3%|▎         | 31/1000 [01:20<37:11,  2.30s/it, lr=0.0001, step_loss=0.08]
# Steps:   3%|▎         | 31/1000 [01:21<37:11,  2.30s/it, lr=0.0001, step_loss=0.0514]
# Steps:   3%|▎         | 32/1000 [01:21<29:29,  1.83s/it, lr=0.0001, step_loss=0.0514]
# Steps:   3%|▎         | 32/1000 [01:21<29:29,  1.83s/it, lr=0.0001, step_loss=0.0449]04/15/2024 03:31:25 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.52it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.73it/s]
#
# Steps:   3%|▎         | 33/1000 [01:30<1:02:50,  3.90s/it, lr=0.0001, step_loss=0.0449]
# Steps:   3%|▎         | 33/1000 [01:30<1:02:50,  3.90s/it, lr=0.0001, step_loss=0.0446]
# Steps:   3%|▎         | 34/1000 [01:31<47:47,  2.97s/it, lr=0.0001, step_loss=0.0446]
# Steps:   3%|▎         | 34/1000 [01:31<47:47,  2.97s/it, lr=0.0001, step_loss=0.0452]
# Steps:   4%|▎         | 35/1000 [01:32<37:20,  2.32s/it, lr=0.0001, step_loss=0.0452]
# Steps:   4%|▎         | 35/1000 [01:32<37:20,  2.32s/it, lr=0.0001, step_loss=0.0442]
# Steps:   4%|▎         | 36/1000 [01:32<29:30,  1.84s/it, lr=0.0001, step_loss=0.0442]
# Steps:   4%|▎         | 36/1000 [01:32<29:30,  1.84s/it, lr=0.0001, step_loss=0.0668]04/15/2024 03:31:36 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   4%|▎         | 37/1000 [01:41<1:03:03,  3.93s/it, lr=0.0001, step_loss=0.0668]
# Steps:   4%|▎         | 37/1000 [01:41<1:03:03,  3.93s/it, lr=0.0001, step_loss=0.0713]
# Steps:   4%|▍         | 38/1000 [01:42<47:55,  2.99s/it, lr=0.0001, step_loss=0.0713]
# Steps:   4%|▍         | 38/1000 [01:42<47:55,  2.99s/it, lr=0.0001, step_loss=0.0587]
# Steps:   4%|▍         | 39/1000 [01:43<37:29,  2.34s/it, lr=0.0001, step_loss=0.0587]
# Steps:   4%|▍         | 39/1000 [01:43<37:29,  2.34s/it, lr=0.0001, step_loss=0.0444]
# Steps:   4%|▍         | 40/1000 [01:43<29:35,  1.85s/it, lr=0.0001, step_loss=0.0444]
# Steps:   4%|▍         | 40/1000 [01:43<29:35,  1.85s/it, lr=0.0001, step_loss=0.0868]04/15/2024 03:31:48 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.54it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.87it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.73it/s]
#
# Steps:   4%|▍         | 41/1000 [01:52<1:01:36,  3.85s/it, lr=0.0001, step_loss=0.0868]
# Steps:   4%|▍         | 41/1000 [01:52<1:01:36,  3.85s/it, lr=0.0001, step_loss=0.0555]
# Steps:   4%|▍         | 42/1000 [01:53<46:53,  2.94s/it, lr=0.0001, step_loss=0.0555]
# Steps:   4%|▍         | 42/1000 [01:53<46:53,  2.94s/it, lr=0.0001, step_loss=0.0326]
# Steps:   4%|▍         | 43/1000 [01:54<36:36,  2.29s/it, lr=0.0001, step_loss=0.0326]
# Steps:   4%|▍         | 43/1000 [01:54<36:36,  2.29s/it, lr=0.0001, step_loss=0.0226]
# Steps:   4%|▍         | 44/1000 [01:54<29:01,  1.82s/it, lr=0.0001, step_loss=0.0226]
# Steps:   4%|▍         | 44/1000 [01:54<29:01,  1.82s/it, lr=0.0001, step_loss=0.0701]04/15/2024 03:31:58 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   4%|▍         | 45/1000 [02:03<1:02:49,  3.95s/it, lr=0.0001, step_loss=0.0701]
# Steps:   4%|▍         | 45/1000 [02:03<1:02:49,  3.95s/it, lr=0.0001, step_loss=0.0595]
# Steps:   5%|▍         | 46/1000 [02:04<47:48,  3.01s/it, lr=0.0001, step_loss=0.0595]
# Steps:   5%|▍         | 46/1000 [02:04<47:48,  3.01s/it, lr=0.0001, step_loss=0.0437]
# Steps:   5%|▍         | 47/1000 [02:05<37:09,  2.34s/it, lr=0.0001, step_loss=0.0437]
# Steps:   5%|▍         | 47/1000 [02:05<37:09,  2.34s/it, lr=0.0001, step_loss=0.0273]
# Steps:   5%|▍         | 48/1000 [02:05<29:24,  1.85s/it, lr=0.0001, step_loss=0.0273]
# Steps:   5%|▍         | 48/1000 [02:06<29:24,  1.85s/it, lr=0.0001, step_loss=0.0377]04/15/2024 03:32:10 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.87it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.75it/s]
#
# Steps:   5%|▍         | 49/1000 [02:14<1:02:41,  3.96s/it, lr=0.0001, step_loss=0.0377]
# Steps:   5%|▍         | 49/1000 [02:14<1:02:41,  3.96s/it, lr=0.0001, step_loss=0.0383]
# Steps:   5%|▌         | 50/1000 [02:15<47:37,  3.01s/it, lr=0.0001, step_loss=0.0383]
# Steps:   5%|▌         | 50/1000 [02:15<47:37,  3.01s/it, lr=0.0001, step_loss=0.0819]
# Steps:   5%|▌         | 51/1000 [02:16<37:00,  2.34s/it, lr=0.0001, step_loss=0.0819]
# Steps:   5%|▌         | 51/1000 [02:16<37:00,  2.34s/it, lr=0.0001, step_loss=0.0702]
# Steps:   5%|▌         | 52/1000 [02:17<29:19,  1.86s/it, lr=0.0001, step_loss=0.0702]
# Steps:   5%|▌         | 52/1000 [02:17<29:19,  1.86s/it, lr=0.0001, step_loss=0.186] 04/15/2024 03:32:21 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.91it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  1.76it/s]
#
# Steps:   5%|▌         | 53/1000 [02:26<1:05:19,  4.14s/it, lr=0.0001, step_loss=0.186]
# Steps:   5%|▌         | 53/1000 [02:26<1:05:19,  4.14s/it, lr=0.0001, step_loss=0.0625]
# Steps:   5%|▌         | 54/1000 [02:27<49:29,  3.14s/it, lr=0.0001, step_loss=0.0625]
# Steps:   5%|▌         | 54/1000 [02:27<49:29,  3.14s/it, lr=0.0001, step_loss=0.0647]
# Steps:   6%|▌         | 55/1000 [02:28<38:18,  2.43s/it, lr=0.0001, step_loss=0.0647]
# Steps:   6%|▌         | 55/1000 [02:28<38:18,  2.43s/it, lr=0.0001, step_loss=0.0674]
# Steps:   6%|▌         | 56/1000 [02:28<30:10,  1.92s/it, lr=0.0001, step_loss=0.0674]
# Steps:   6%|▌         | 56/1000 [02:28<30:10,  1.92s/it, lr=0.0001, step_loss=0.0413]04/15/2024 03:32:33 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.16it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   6%|▌         | 57/1000 [02:37<1:02:12,  3.96s/it, lr=0.0001, step_loss=0.0413]
# Steps:   6%|▌         | 57/1000 [02:37<1:02:12,  3.96s/it, lr=0.0001, step_loss=0.0534]
# Steps:   6%|▌         | 58/1000 [02:38<47:15,  3.01s/it, lr=0.0001, step_loss=0.0534]
# Steps:   6%|▌         | 58/1000 [02:38<47:15,  3.01s/it, lr=0.0001, step_loss=0.0289]
# Steps:   6%|▌         | 59/1000 [02:39<36:43,  2.34s/it, lr=0.0001, step_loss=0.0289]
# Steps:   6%|▌         | 59/1000 [02:39<36:43,  2.34s/it, lr=0.0001, step_loss=0.0427]
# Steps:   6%|▌         | 60/1000 [02:39<29:03,  1.85s/it, lr=0.0001, step_loss=0.0427]
# Steps:   6%|▌         | 60/1000 [02:40<29:03,  1.85s/it, lr=0.0001, step_loss=0.0276]04/15/2024 03:32:44 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   6%|▌         | 61/1000 [02:48<1:01:01,  3.90s/it, lr=0.0001, step_loss=0.0276]
# Steps:   6%|▌         | 61/1000 [02:48<1:01:01,  3.90s/it, lr=0.0001, step_loss=0.056]
# Steps:   6%|▌         | 62/1000 [02:49<46:20,  2.96s/it, lr=0.0001, step_loss=0.056]
# Steps:   6%|▌         | 62/1000 [02:49<46:20,  2.96s/it, lr=0.0001, step_loss=0.0786]
# Steps:   6%|▋         | 63/1000 [02:50<36:12,  2.32s/it, lr=0.0001, step_loss=0.0786]
# Steps:   6%|▋         | 63/1000 [02:50<36:12,  2.32s/it, lr=0.0001, step_loss=0.0308]
# Steps:   6%|▋         | 64/1000 [02:50<28:40,  1.84s/it, lr=0.0001, step_loss=0.0308]
# Steps:   6%|▋         | 64/1000 [02:50<28:40,  1.84s/it, lr=0.0001, step_loss=0.0628]04/15/2024 03:32:55 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.54it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.74it/s]
#
# Steps:   6%|▋         | 65/1000 [02:59<1:00:48,  3.90s/it, lr=0.0001, step_loss=0.0628]
# Steps:   6%|▋         | 65/1000 [02:59<1:00:48,  3.90s/it, lr=0.0001, step_loss=0.0416]
# Steps:   7%|▋         | 66/1000 [03:00<46:19,  2.98s/it, lr=0.0001, step_loss=0.0416]
# Steps:   7%|▋         | 66/1000 [03:00<46:19,  2.98s/it, lr=0.0001, step_loss=0.0385]
# Steps:   7%|▋         | 67/1000 [03:01<36:02,  2.32s/it, lr=0.0001, step_loss=0.0385]
# Steps:   7%|▋         | 67/1000 [03:01<36:02,  2.32s/it, lr=0.0001, step_loss=0.0637]
# Steps:   7%|▋         | 68/1000 [03:01<28:35,  1.84s/it, lr=0.0001, step_loss=0.0637]
# Steps:   7%|▋         | 68/1000 [03:02<28:35,  1.84s/it, lr=0.0001, step_loss=0.054] 04/15/2024 03:33:06 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.54it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.75it/s]
#
# Steps:   7%|▋         | 69/1000 [03:10<59:17,  3.82s/it, lr=0.0001, step_loss=0.054]
# Steps:   7%|▋         | 69/1000 [03:10<59:17,  3.82s/it, lr=0.0001, step_loss=0.038]
# Steps:   7%|▋         | 70/1000 [03:11<45:18,  2.92s/it, lr=0.0001, step_loss=0.038]
# Steps:   7%|▋         | 70/1000 [03:11<45:18,  2.92s/it, lr=0.0001, step_loss=0.0311]
# Steps:   7%|▋         | 71/1000 [03:12<35:27,  2.29s/it, lr=0.0001, step_loss=0.0311]
# Steps:   7%|▋         | 71/1000 [03:12<35:27,  2.29s/it, lr=0.0001, step_loss=0.0541]
# Steps:   7%|▋         | 72/1000 [03:12<28:07,  1.82s/it, lr=0.0001, step_loss=0.0541]
# Steps:   7%|▋         | 72/1000 [03:12<28:07,  1.82s/it, lr=0.0001, step_loss=0.0339]04/15/2024 03:33:16 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.75it/s]
#
# Steps:   7%|▋         | 73/1000 [03:21<59:56,  3.88s/it, lr=0.0001, step_loss=0.0339]
# Steps:   7%|▋         | 73/1000 [03:21<59:56,  3.88s/it, lr=0.0001, step_loss=0.0203]
# Steps:   7%|▋         | 74/1000 [03:22<45:35,  2.95s/it, lr=0.0001, step_loss=0.0203]
# Steps:   7%|▋         | 74/1000 [03:22<45:35,  2.95s/it, lr=0.0001, step_loss=0.0579]
# Steps:   8%|▊         | 75/1000 [03:22<35:29,  2.30s/it, lr=0.0001, step_loss=0.0579]
# Steps:   8%|▊         | 75/1000 [03:23<35:29,  2.30s/it, lr=0.0001, step_loss=0.0912]
# Steps:   8%|▊         | 76/1000 [03:23<28:12,  1.83s/it, lr=0.0001, step_loss=0.0912]
# Steps:   8%|▊         | 76/1000 [03:23<28:12,  1.83s/it, lr=0.0001, step_loss=0.0233]04/15/2024 03:33:27 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.58it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.90it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  1.76it/s]
#
# Steps:   8%|▊         | 77/1000 [03:32<58:48,  3.82s/it, lr=0.0001, step_loss=0.0233]
# Steps:   8%|▊         | 77/1000 [03:32<58:48,  3.82s/it, lr=0.0001, step_loss=0.0634]
# Steps:   8%|▊         | 78/1000 [03:32<44:43,  2.91s/it, lr=0.0001, step_loss=0.0634]
# Steps:   8%|▊         | 78/1000 [03:33<44:43,  2.91s/it, lr=0.0001, step_loss=0.0158]
# Steps:   8%|▊         | 79/1000 [03:33<35:05,  2.29s/it, lr=0.0001, step_loss=0.0158]
# Steps:   8%|▊         | 79/1000 [03:33<35:05,  2.29s/it, lr=0.0001, step_loss=0.0489]
# Steps:   8%|▊         | 80/1000 [03:34<27:50,  1.82s/it, lr=0.0001, step_loss=0.0489]
# Steps:   8%|▊         | 80/1000 [03:34<27:50,  1.82s/it, lr=0.0001, step_loss=0.046] 04/15/2024 03:33:38 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.52it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.89it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.17it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  1.75it/s]
#
# Steps:   8%|▊         | 81/1000 [03:43<1:01:04,  3.99s/it, lr=0.0001, step_loss=0.046]
# Steps:   8%|▊         | 81/1000 [03:43<1:01:04,  3.99s/it, lr=0.0001, step_loss=0.0623]
# Steps:   8%|▊         | 82/1000 [03:44<46:23,  3.03s/it, lr=0.0001, step_loss=0.0623]
# Steps:   8%|▊         | 82/1000 [03:44<46:23,  3.03s/it, lr=0.0001, step_loss=0.0542]
# Steps:   8%|▊         | 83/1000 [03:45<36:07,  2.36s/it, lr=0.0001, step_loss=0.0542]
# Steps:   8%|▊         | 83/1000 [03:45<36:07,  2.36s/it, lr=0.0001, step_loss=0.0521]
# Steps:   8%|▊         | 84/1000 [03:45<28:30,  1.87s/it, lr=0.0001, step_loss=0.0521]
# Steps:   8%|▊         | 84/1000 [03:45<28:30,  1.87s/it, lr=0.0001, step_loss=0.0379]04/15/2024 03:33:50 - INFO - __main__ - Running validation...
# ...
# Steps:  98%|█████████▊| 983/1000 [46:26<00:39,  2.34s/it, lr=0.0001, step_loss=0.0471]
# Steps:  98%|█████████▊| 983/1000 [46:26<00:39,  2.34s/it, lr=0.0001, step_loss=0.0635]
# Steps:  98%|█████████▊| 984/1000 [46:27<00:29,  1.85s/it, lr=0.0001, step_loss=0.0635]
# Steps:  98%|█████████▊| 984/1000 [46:27<00:29,  1.85s/it, lr=0.0001, step_loss=0.0604]04/15/2024 04:16:31 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:04<00:01,  1.13it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.70it/s]
#
# Steps:  98%|█████████▊| 985/1000 [46:35<00:58,  3.89s/it, lr=0.0001, step_loss=0.0604]
# Steps:  98%|█████████▊| 985/1000 [46:35<00:58,  3.89s/it, lr=0.0001, step_loss=0.0574]
# Steps:  99%|█████████▊| 986/1000 [46:36<00:41,  2.97s/it, lr=0.0001, step_loss=0.0574]
# Steps:  99%|█████████▊| 986/1000 [46:36<00:41,  2.97s/it, lr=0.0001, step_loss=0.0328]
# Steps:  99%|█████████▊| 987/1000 [46:37<00:30,  2.32s/it, lr=0.0001, step_loss=0.0328]
# Steps:  99%|█████████▊| 987/1000 [46:37<00:30,  2.32s/it, lr=0.0001, step_loss=0.198]
# Steps:  99%|█████████▉| 988/1000 [46:38<00:22,  1.84s/it, lr=0.0001, step_loss=0.198]
# Steps:  99%|█████████▉| 988/1000 [46:38<00:22,  1.84s/it, lr=0.0001, step_loss=0.0424]04/15/2024 04:16:42 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:04<00:01,  1.14it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.70it/s]
#
# Steps:  99%|█████████▉| 989/1000 [46:46<00:42,  3.84s/it, lr=0.0001, step_loss=0.0424]
# Steps:  99%|█████████▉| 989/1000 [46:46<00:42,  3.84s/it, lr=0.0001, step_loss=0.0585]
# Steps:  99%|█████████▉| 990/1000 [46:47<00:29,  2.93s/it, lr=0.0001, step_loss=0.0585]
# Steps:  99%|█████████▉| 990/1000 [46:47<00:29,  2.93s/it, lr=0.0001, step_loss=0.0521]
# Steps:  99%|█████████▉| 991/1000 [46:48<00:20,  2.29s/it, lr=0.0001, step_loss=0.0521]
# Steps:  99%|█████████▉| 991/1000 [46:48<00:20,  2.29s/it, lr=0.0001, step_loss=0.0124]
# Steps:  99%|█████████▉| 992/1000 [46:48<00:14,  1.82s/it, lr=0.0001, step_loss=0.0124]
# Steps:  99%|█████████▉| 992/1000 [46:48<00:14,  1.82s/it, lr=0.0001, step_loss=0.0715]04/15/2024 04:16:53 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.52it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.87it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:04<00:01,  1.13it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.70it/s]
#
# Steps:  99%|█████████▉| 993/1000 [46:57<00:27,  3.93s/it, lr=0.0001, step_loss=0.0715]
# Steps:  99%|█████████▉| 993/1000 [46:57<00:27,  3.93s/it, lr=0.0001, step_loss=0.0367]
# Steps:  99%|█████████▉| 994/1000 [46:58<00:17,  3.00s/it, lr=0.0001, step_loss=0.0367]
# Steps:  99%|█████████▉| 994/1000 [46:58<00:17,  3.00s/it, lr=0.0001, step_loss=0.0427]
# Steps: 100%|█████████▉| 995/1000 [46:59<00:11,  2.34s/it, lr=0.0001, step_loss=0.0427]
# Steps: 100%|█████████▉| 995/1000 [46:59<00:11,  2.34s/it, lr=0.0001, step_loss=0.0212]
# Steps: 100%|█████████▉| 996/1000 [47:00<00:07,  1.85s/it, lr=0.0001, step_loss=0.0212]
# Steps: 100%|█████████▉| 996/1000 [47:00<00:07,  1.85s/it, lr=0.0001, step_loss=0.0343]04/15/2024 04:17:04 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.54it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.88it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:04<00:01,  1.14it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:04<00:00,  1.71it/s]
#
# Steps: 100%|█████████▉| 997/1000 [47:08<00:11,  3.95s/it, lr=0.0001, step_loss=0.0343]
# Steps: 100%|█████████▉| 997/1000 [47:09<00:11,  3.95s/it, lr=0.0001, step_loss=0.0426]
# Steps: 100%|█████████▉| 998/1000 [47:09<00:06,  3.01s/it, lr=0.0001, step_loss=0.0426]
# Steps: 100%|█████████▉| 998/1000 [47:09<00:06,  3.01s/it, lr=0.0001, step_loss=0.053]
# Steps: 100%|█████████▉| 999/1000 [47:10<00:02,  2.34s/it, lr=0.0001, step_loss=0.053]
# Steps: 100%|█████████▉| 999/1000 [47:10<00:02,  2.34s/it, lr=0.0001, step_loss=0.0614]
# Steps: 100%|██████████| 1000/1000 [47:11<00:00,  1.86s/it, lr=0.0001, step_loss=0.0614]04/15/2024 04:17:15 - INFO - accelerate.accelerator - Saving current state to X:\Jupyter\csc413_project\checkpoint-1000
# 04/15/2024 04:17:19 - INFO - accelerate.checkpointing - Model weights saved in X:\Jupyter\csc413_project\checkpoint-1000\model.safetensors
# 04/15/2024 04:17:19 - INFO - accelerate.checkpointing - Optimizer state saved in X:\Jupyter\csc413_project\checkpoint-1000\optimizer.bin
# 04/15/2024 04:17:19 - INFO - accelerate.checkpointing - Scheduler state saved in X:\Jupyter\csc413_project\checkpoint-1000\scheduler.bin
# 04/15/2024 04:17:19 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in X:\Jupyter\csc413_project\checkpoint-1000\sampler.bin
# 04/15/2024 04:17:19 - INFO - accelerate.checkpointing - Random states saved in X:\Jupyter\csc413_project\checkpoint-1000\random_states_0.pkl
# Model weights saved in X:/Jupyter/csc413_project/checkpoint-1000/pytorch_lora_weights.safetensors
# 04/15/2024 04:17:19 - INFO - __main__ - Saved state to X:\Jupyter\csc413_project\checkpoint-1000
#
# Steps: 100%|██████████| 1000/1000 [47:15<00:00,  1.86s/it, lr=0.0001, step_loss=0.0435]04/15/2024 04:17:19 - INFO - __main__ - Running validation...
# Generating 1 images with prompt: An illustration of Pikachu, a yellow, electric-type Pokemon.
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.56it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:01<00:02,  1.86it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:03<00:01,  1.19it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:03<00:00,  1.78it/s]
# Model weights saved in X:/Jupyter/csc413_project/pytorch_lora_weights.safetensors
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
#
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]{'latents_std', 'latents_mean', 'scaling_factor', 'force_upcast'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  14%|█▍        | 1/7 [00:00<00:03,  1.73it/s]{'time_embedding_act_fn', 'conv_in_kernel', 'cross_attention_norm', 'projection_class_embeddings_input_dim', 'resnet_out_scale_factor', 'resnet_time_scale_shift', 'upcast_attention', 'addition_embed_type_num_heads', 'time_cond_proj_dim', 'mid_block_type', 'encoder_hid_dim_type', 'addition_time_embed_dim', 'reverse_transformer_layers_per_block', 'mid_block_only_cross_attention', 'time_embedding_type', 'encoder_hid_dim', 'only_cross_attention', 'class_embed_type', 'dual_cross_attention', 'num_class_embeds', 'class_embeddings_concat', 'dropout', 'addition_embed_type', 'time_embedding_dim', 'use_linear_projection', 'transformer_layers_per_block', 'conv_out_kernel', 'num_attention_heads', 'timestep_post_act', 'attention_type', 'resnet_skip_time_act'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  29%|██▊       | 2/7 [00:06<00:18,  3.66s/it]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  43%|████▎     | 3/7 [00:07<00:09,  2.44s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of runwayml/stable-diffusion-v1-5.
# Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of runwayml/stable-diffusion-v1-5.
#
#
# Loading pipeline components...:  71%|███████▏  | 5/7 [00:09<00:03,  1.71s/it]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of runwayml/stable-diffusion-v1-5.
# {'prediction_type', 'timestep_spacing'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of runwayml/stable-diffusion-v1-5.
#
# Loading pipeline components...: 100%|██████████| 7/7 [00:09<00:00,  1.39s/it]
# Loading unet.
#
#
# 0%|          | 0/30 [00:00<?, ?it/s]
#
# 3%|▎         | 1/30 [00:00<00:09,  2.91it/s]
#
# 10%|█         | 3/30 [00:00<00:04,  6.31it/s]
#
# 17%|█▋        | 5/30 [00:00<00:03,  8.24it/s]
#
# 23%|██▎       | 7/30 [00:00<00:02,  9.08it/s]
#
# 30%|███       | 9/30 [00:01<00:02,  9.58it/s]
#
# 37%|███▋      | 11/30 [00:01<00:01, 10.17it/s]
#
# 43%|████▎     | 13/30 [00:01<00:01, 10.46it/s]
#
# 50%|█████     | 15/30 [00:01<00:01, 10.52it/s]
#
# 57%|█████▋    | 17/30 [00:01<00:01, 10.89it/s]
#
# 63%|██████▎   | 19/30 [00:01<00:01, 10.78it/s]
#
# 70%|███████   | 21/30 [00:02<00:00, 11.03it/s]
#
# 77%|███████▋  | 23/30 [00:02<00:00, 10.91it/s]
#
# 83%|████████▎ | 25/30 [00:02<00:00, 11.12it/s]
#
# 90%|█████████ | 27/30 [00:02<00:00, 10.99it/s]
#
# 97%|█████████▋| 29/30 [00:02<00:00, 10.88it/s]
# 100%|██████████| 30/30 [00:02<00:00, 10.05it/s]
# wandb: Waiting for W&B process to finish... (success).
# wandb: - 88.721 MB of 88.721 MB uploaded (0.000 MB deduped)
# wandb: \ 88.721 MB of 88.955 MB uploaded (0.000 MB deduped)
# wandb: | 88.721 MB of 88.955 MB uploaded (0.000 MB deduped)
# wandb:
# wandb: Run summary:
# wandb: train_loss 0.04346
# wandb:
# wandb:  View run splendid-mountain-37 at: https://wandb.ai/tonyxichen/text2image-fine-tune/runs/o5c5vb4a
# wandb: Synced 5 W&B file(s), 251 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: .\wandb\run-20240415_033003-o5c5vb4a\logs
# C:\Users\Tony\AppData\Local\Programs\Python\Python310\lib\site-packages\wandb\sdk\wandb_run.py:2085: UserWarning: Run (o5c5vb4a) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
# lambda data: self._console_raw_callback("stderr", data),
#
# Steps: 100%|██████████| 1000/1000 [47:42<00:00,  2.86s/it, lr=0.0001, step_loss=0.0435]
